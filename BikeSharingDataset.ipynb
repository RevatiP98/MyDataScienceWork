# %%
#BIKE SHARING DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import pandas as pd
df_bike=pd.read_csv('bike.csv')

# %%
df_bike
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
df_bike.shape
# Out:
# (730, 16)

# %%
df_bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
df_bike.isnull().T
# Out:
#               0      1      2      3      4      5      6      7      8    \
# instant     False  False  False  False  False  False  False  False  False
# dteday      False  False  False  False  False  False  False  False  False
# season      False  False  False  False  False  False  False  False  False
# yr          False  False  False  False  False  False  False  False  False
# mnth        False  False  False  False  False  False  False  False  False
# holiday     False  False  False  False  False  False  False  False  False
# weekday     False  False  False  False  False  False  False  False  False
# workingday  False  False  False  False  False  False  False  False  False
# weathersit  False  False  False  False  False  False  False  False  False
# temp        False  False  False  False  False  False  False  False  False
# atemp       False  False  False  False  False  False  False  False  False
# hum         False  False  False  False  False  False  False  False  False
# ...

# %%
df_bike.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df_bike.duplicated().sum()
# Out:
# 0

# %%
df_bike.describe().T
# Out:
#             count         mean          std        min          25%  \
# instant     730.0   365.500000   210.877136   1.000000   183.250000
# season      730.0     2.498630     1.110184   1.000000     2.000000
# yr          730.0     0.500000     0.500343   0.000000     0.000000
# mnth        730.0     6.526027     3.450215   1.000000     4.000000
# holiday     730.0     0.028767     0.167266   0.000000     0.000000
# weekday     730.0     2.997260     2.006161   0.000000     1.000000
# workingday  730.0     0.683562     0.465405   0.000000     0.000000
# weathersit  730.0     1.394521     0.544807   1.000000     1.000000
# temp        730.0    20.319259     7.506729   2.424346    13.811885
# atemp       730.0    23.726322     8.150308   3.953480    16.889713
# hum         730.0    62.765175    14.237589   0.000000    52.000000
# windspeed   730.0    12.763620     5.195841   1.500244     9.041650
# casual      730.0   849.249315   686.479875   2.000000   316.250000
# ...

# %%
df_bike.plot.scatter(x='casual', y='cnt', title= "Scatter plot between two variables X and Y");
plot.show(block=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13752\2960301104.py in <module>
#       1 df_bike.plot.scatter(x='casual', y='cnt', title= "Scatter plot between two variables X and Y");
# ----> 2 plot.show(block=True);
#
# NameError: name 'plot' is not defined

# %%
dum_bike=df_bike

# %%
dum_bike
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
dum_bike
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
dum_bike.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
dum_bike.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
dum_bike.nunique()
# Out:
# instant       730
# dteday        730
# season          4
# yr              2
# mnth           12
# holiday         2
# weekday         7
# workingday      2
# weathersit      3
# temp          498
# atemp         689
# hum           594
# windspeed     649
# casual        605
# registered    678
# cnt           695
# dtype: int64

# %%
dum_bike.corr()
# Out:
#              instant        season            yr          mnth   holiday  \
# instant     1.000000  4.135867e-01  8.660262e-01  4.982507e-01  0.016275
# season      0.413587  1.000000e+00 -2.248195e-17  8.310321e-01 -0.010868
# yr          0.866026 -2.248195e-17  1.000000e+00 -2.470170e-17  0.008195
# mnth        0.498251  8.310321e-01 -2.470170e-17  1.000000e+00  0.018905
# holiday     0.016275 -1.086804e-02  8.195345e-03  1.890483e-02  1.000000
# weekday    -0.000023 -3.081198e-03 -5.466369e-03  9.522969e-03 -0.101962
# workingday -0.004619  1.376178e-02 -2.945396e-03 -4.687953e-03 -0.252948
# weathersit -0.021862  2.130636e-02 -5.032247e-02  4.561335e-02 -0.034395
# temp        0.150738  3.333607e-01  4.878919e-02  2.190833e-01 -0.028764
# atemp       0.152773  3.420139e-01  4.721519e-02  2.264302e-01 -0.032703
# hum         0.016080  2.082196e-01 -1.125471e-01  2.249368e-01 -0.015662
# windspeed  -0.112667 -2.296069e-01 -1.162435e-02 -2.080131e-01  0.006257
# ...

# %%
# Rename the columns of df2_melted: df2_tidy
dum_bike = dum_bike.rename(columns = {'yr': 'Year', 'mnth': 'Month','hum': 'Humidity','cnt':'Count'}, inplace = False)
dum_bike.columns
# Out:
# Index(['instant', 'dteday', 'season', 'Year', 'Month', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'Humidity', 'windspeed',
#        'casual', 'registered', 'Count'],
#       dtype='object')

# %%
dum_bike.drop(['instant','dteday'],axis='columns', inplace=True)

# %%
dum_bike.drop(['atemp'],axis='columns', inplace=True)

# %%
#After droping column instent, date, atemp
dum_bike.corr()
# Out:
#                   season          Year         Month   holiday   weekday  \
# season      1.000000e+00 -2.248195e-17  8.310321e-01 -0.010868 -0.003081
# Year       -2.248195e-17  1.000000e+00 -2.470170e-17  0.008195 -0.005466
# Month       8.310321e-01 -2.470170e-17  1.000000e+00  0.018905  0.009523
# holiday    -1.086804e-02  8.195345e-03  1.890483e-02  1.000000 -0.101962
# weekday    -3.081198e-03 -5.466369e-03  9.522969e-03 -0.101962  1.000000
# workingday  1.376178e-02 -2.945396e-03 -4.687953e-03 -0.252948  0.035800
# weathersit  2.130636e-02 -5.032247e-02  4.561335e-02 -0.034395  0.031112
# temp        3.333607e-01  4.878919e-02  2.190833e-01 -0.028764 -0.000168
# Humidity    2.082196e-01 -1.125471e-01  2.249368e-01 -0.015662 -0.052290
# windspeed  -2.296069e-01 -1.162435e-02 -2.080131e-01  0.006257  0.014283
# casual      2.087373e-01  2.505017e-01  1.212079e-01  0.054055  0.059978
# registered  4.103102e-01  5.969106e-01  2.919516e-01 -0.109142  0.057427
# ...

# %%
plt.figure(figsize=(16,8))
sns.heatmap(dum_bike.corr(),annot=True,cmap='summer')
plt.title("Heatmap of the Bike Sharing Dataset")
# Out:
# Text(0.5, 1.0, 'Heatmap of the Bike Sharing Dataset')

# %%
dum_bike.columns
# Out:
# Index(['season', 'Year', 'Month', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'Humidity', 'windspeed', 'casual',
#        'registered', 'Count'],
#       dtype='object')

# %%
dum_bike['season'].value_counts(ascending=True)
# Out:
# 4    178
# 1    180
# 2    184
# 3    188
# Name: season, dtype: int64

# %%
import matplotlib.pyplot as plt
#import numpy as np
#import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
type_labels = dum_bike.season.sort_values().index 
type_counts = dum_bike.season.sort_values()

# %%
#type_labels
type_counts
# Out:
# 0      1
# 381    1
# 382    1
# 383    1
# 384    1
#       ..
# 326    4
# 327    4
# 328    4
# 308    4
# 338    4
# Name: season, Length: 730, dtype: int64

# %%
#Scatter plot of orignal dataset
df_bike.plot.scatter(x='casual', y='cnt', title= "Scatter plot between two variables X and Y");
plot.show(block=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13752\1104640095.py in <module>
#       1 #Scatter plot of orignal dataset
#       2 df_bike.plot.scatter(x='casual', y='cnt', title= "Scatter plot between two variables X and Y");
# ----> 3 plot.show(block=True);
#
# NameError: name 'plot' is not defined

# %%
#Pie plot for Season 
lable=['Spring','Summer','fall', 'winter']
count=[len(dum_bike[dum_bike['season'] == '1']),len(dum_bike[dum_bike['season'] == '2']),
      len(dum_bike[dum_bike['season'] == '3']),len(dum_bike[dum_bike['season'] == '4'])]
colors = sns.color_palette('pastel')[0:5]
plt.pie(count, labels=lable, colors = colors, autopct='%.0f%%')
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13752\2546777589.py:6: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   plt.pie(count, labels=lable, colors = colors, autopct='%.0f%%')

# %%
#season : season (1:springer, 2:summer, 3:fall, 4:winter)
ax=sns.countplot(data = dum_bike , x = 'season')

plt.xticks(np.arange(4),['Spring','Summer','Fall','Winter'])
#for p in ax.patches:
#        ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
#ax.legend(loc='upper center', title='Season')
plt.show()

# %%
fig=plt.figure(figsize=(10,8))
ax=sns.countplot(data =dum_bike, x ='season', hue='season', order=dum_bike['season'].value_counts().index)
for p in ax.patches:
        ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))
ax.legend(loc='upper left', title='Season')
plt.show()

# %%
#data = np.random.normal(100, 20, 200)
 
fig = plt.figure(figsize =(10, 7))
# Creating plot
plt.boxplot(dum_bike)
 
# show plot
plt.show()

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'casual', data = dum_bike)
# Out:
# <AxesSubplot:xlabel='casual'>

# %%
dum_bike
# Out:
#      season  Year  Month  holiday  weekday  workingday  weathersit       temp  \
# 0         1     0      1        0        6           0           2  14.110847
# 1         1     0      1        0        0           0           2  14.902598
# 2         1     0      1        0        1           1           1   8.050924
# 3         1     0      1        0        2           1           1   8.200000
# 4         1     0      1        0        3           1           1   9.305237
# ..      ...   ...    ...      ...      ...         ...         ...        ...
# 725       1     1     12        0        4           1           2  10.420847
# 726       1     1     12        0        5           1           2  10.386653
# 727       1     1     12        0        6           0           2  10.386653
# 728       1     1     12        0        0           0           1  10.489153
# 729       1     1     12        0        1           1           2   8.849153
#
# ...

# %%
from scipy import stats
 
z = np.abs(stats.zscore(dum_bike['casual']))
print(z)
# Out:
# 0      0.755455
# 1      1.046996
# 2      1.063031
# 3      1.080523
# 4      1.118424
#          ...
# 725    0.877902
# 726    0.299193
# 727    1.006180
# 728    0.707351
# 729    0.598023
# Name: casual, Length: 730, dtype: float64

# %%
fig = plt.figure(figsize =(10, 7))
# Creating plot
plt.boxplot(dum_bike['casual'])
 
# show plot
plt.show()

# %%
# Position of the Outlier
outliers=np.where(dum_bike['casual']>2300)
outliers
# Out:
# (array([148, 184, 196, 246, 281, 440, 446, 454, 455, 461, 468, 469, 475,
#         489, 496, 503, 504, 510, 511, 512, 517, 518, 524, 531, 532, 538,
#         539, 549, 559, 567, 580, 594, 608, 609, 616, 622, 629, 630, 636,
#         643, 657, 664], dtype=int64),)

# %%
dum_bike.drop(outliers[0],inplace=True)

# %%
outliers1=np.where(dum_bike['casual']>2220)
outliers1
# Out:
# (array([140, 148, 183, 184, 196, 246, 280, 281, 440, 446, 454, 455, 461,
#         462, 468, 469, 475, 483, 489, 496, 503, 504, 510, 511, 512, 517,
#         518, 524, 525, 531, 532, 538, 539, 549, 559, 567, 573, 580, 587,
#         594, 608, 609, 616, 622, 629, 630, 636, 643, 650, 657, 664, 679],
#        dtype=int64),)

# %%
dum_bike.drop(outliers1[0],inplace=True)

# %%
id='532 '
dum_bike = dum_bike.drop(dum_bike.loc[dum_bike.index==id].index)
print(dum_bike)
# Out:
#      season  Year  Month  holiday  weekday  workingday  weathersit       temp  \
# 0         1     0      1        0        6           0           2  14.110847
# 1         1     0      1        0        0           0           2  14.902598
# 2         1     0      1        0        1           1           1   8.050924
# 3         1     0      1        0        2           1           1   8.200000
# 4         1     0      1        0        3           1           1   9.305237
# ..      ...   ...    ...      ...      ...         ...         ...        ...
# 725       1     1     12        0        4           1           2  10.420847
# 726       1     1     12        0        5           1           2  10.386653
# 727       1     1     12        0        6           0           2  10.386653
# 728       1     1     12        0        0           0           1  10.489153
# 729       1     1     12        0        1           1           2   8.849153
#
# ...

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'casual', data = dum_bike)
# Out:
# <AxesSubplot:xlabel='casual'>

# %%
id=446
dum_bike = dum_bike.drop(dum_bike.loc[dum_bike.index==id].index)
print(dum_bike)
# Out:
#      season  Year  Month  holiday  weekday  workingday  weathersit       temp  \
# 0         1     0      1        0        6           0           2  14.110847
# 1         1     0      1        0        0           0           2  14.902598
# 2         1     0      1        0        1           1           1   8.050924
# 3         1     0      1        0        2           1           1   8.200000
# 4         1     0      1        0        3           1           1   9.305237
# ..      ...   ...    ...      ...      ...         ...         ...        ...
# 725       1     1     12        0        4           1           2  10.420847
# 726       1     1     12        0        5           1           2  10.386653
# 727       1     1     12        0        6           0           2  10.386653
# 728       1     1     12        0        0           0           1  10.489153
# 729       1     1     12        0        1           1           2   8.849153
#
# ...

# %%
#filename=bike.csv
#data = pd.read_csv(filename, sep=' ', encoding="utf-8", index_col=['casual'])
id=' 446 '
dum_bike = dum_bike.drop(dum_bike.loc[dum_bike.index==id].index)
print(dum_bike)
# Out:
#      season  Year  Month  holiday  weekday  workingday  weathersit       temp  \
# 0         1     0      1        0        6           0           2  14.110847
# 1         1     0      1        0        0           0           2  14.902598
# 2         1     0      1        0        1           1           1   8.050924
# 3         1     0      1        0        2           1           1   8.200000
# 4         1     0      1        0        3           1           1   9.305237
# ..      ...   ...    ...      ...      ...         ...         ...        ...
# 725       1     1     12        0        4           1           2  10.420847
# 726       1     1     12        0        5           1           2  10.386653
# 727       1     1     12        0        6           0           2  10.386653
# 728       1     1     12        0        0           0           1  10.489153
# 729       1     1     12        0        1           1           2   8.849153
#
# ...

# %%
outliers2=np.where(dum_bike['casual']>2100)
outliers2
# Out:
# (array([140, 148, 182, 183, 184, 196, 246, 280, 281, 440, 441, 446, 454,
#         455, 461, 462, 468, 469, 475, 483, 489, 490, 496, 497, 503, 504,
#         510, 511, 512, 517, 518, 524, 525, 531, 532, 538, 539, 549, 559,
#         567, 573, 574, 580, 587, 588, 594, 608, 609, 616, 622, 623, 629,
#         630, 636, 643, 650, 657, 658, 664, 679], dtype=int64),)

# %%
#Scatterplot after removing outliers
dum_bike.plot.scatter(x='casual', y='Count', title= "Scatter plot between two variables X and Y");
plot.show(block=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13752\3618103621.py in <module>
#       1 #Scatterplot after removing outliers
#       2 dum_bike.plot.scatter(x='casual', y='Count', title= "Scatter plot between two variables X and Y");
# ----> 3 plot.show(block=True);
#
# NameError: name 'plot' is not defined

# %%
dum_bike.drop(outliers2[0],inplace=True)

# %%
#from scipy.stats import zscore
z_scores = stats.zscore(dum_bike)
#calculate z-scores of `df`
z_scores

abs_z_scores = np.abs(z_scores)
abs_z_scores
#filtered_entries = (abs_z_scores < 3).all(axis=1)
#new_df = dum_bike[filtered_entries]

#print(new_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13392\2469296473.py in <module>
#       1 #from scipy.stats import zscore
# ----> 2 z_scores = stats.zscore(dum_bike)
#       3 #calculate z-scores of `df`
#       4 z_scores
#       5
#
# c:\python38\lib\site-packages\scipy\stats\stats.py in zscore(a, axis, ddof, nan_policy)
#    2472            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2473     """
# -> 2474     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#    2475
#    2476
#
# c:\python38\lib\site-packages\scipy\stats\stats.py in zmap(scores, compare, axis, ddof, nan_policy)
#    2542             isconst = np.apply_along_axis(_isconst, axis, a)
#    2543     else:
# -> 2544         mn = a.mean(axis=axis, keepdims=True)
#    2545         std = a.std(axis=axis, ddof=ddof, keepdims=True)
# ...

# %%
#Scatterplot after removing outliers
dum_bike.plot.scatter(x='casual', y='Count', title= "Scatter plot between two variables X and Y");
plot.show(block=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13752\3618103621.py in <module>
#       1 #Scatterplot after removing outliers
#       2 dum_bike.plot.scatter(x='casual', y='Count', title= "Scatter plot between two variables X and Y");
# ----> 3 plot.show(block=True);
#
# NameError: name 'plot' is not defined

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'casual', data = dum_bike)
# Out:
# <AxesSubplot:xlabel='casual'>

# %%
outliers3=np.where(dum_bike['casual']>2000)
outliers3
# Out:
# (array([140, 147, 148, 182, 183, 184, 196, 197, 246, 280, 281, 440, 441,
#         446, 454, 455, 461, 462, 468, 469, 475, 483, 489, 490, 496, 497,
#         503, 504, 510, 511, 512, 517, 518, 524, 525, 531, 532, 538, 539,
#         549, 559, 567, 573, 574, 580, 587, 588, 594, 608, 609, 616, 622,
#         623, 629, 630, 636, 637, 643, 650, 651, 657, 658, 664, 678, 679],
#        dtype=int64),)

# %%
dum_bike.drop(outliers3[0],inplace=True)

# %%
#Scatterplot after removing outliers
dum_bike.plot.scatter(x='casual', y='Count', title= "Scatter plot between two variables X and Y");
plot.show(block=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13752\3618103621.py in <module>
#       1 #Scatterplot after removing outliers
#       2 dum_bike.plot.scatter(x='casual', y='Count', title= "Scatter plot between two variables X and Y");
# ----> 3 plot.show(block=True);
#
# NameError: name 'plot' is not defined

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'casual', data = dum_bike)
# Out:
# <AxesSubplot:xlabel='casual'>
